# %% [markdown]
# TV SHOWS DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\USER\Desktop\DATA_ANALYSIS-FILES\DATA_ANALYTICS-MetroHub_Course2024\DATA_ANALYSIS_CERTIFICATION\120724_archive_44\TV_show_data_Python.csv")
df.head()
# Out:
#                          Name  \
# 0                Breaking Bad
# 1                     Firefly
# 2  Avatar: The Last Airbender
# 3                    Sherlock
# 4             Attack on Titan
#
#                                              Summary  Average Runtime  \
# 0  Breaking Bad follows protagonist Walter White,...             60.0
# 1  Five hundred years in the future, a renegade c...             64.0
# 2  Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3  Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4  Known in Japan as Shingeki no Kyojin, many yea...             26.0
#
#      End Date Premiere Date                                       Genres  \
# 0  20/01/2008    11/10/2019               ['Drama', 'Crime', 'Thriller']
# 1  20/09/2002    20/12/2002    ['Drama', 'Adventure', 'Science-Fiction']
# 2  21/02/2005    19/07/2008           ['Action', 'Adventure', 'Fantasy']
# ...

# %%
df= df.drop_duplicates().fillna(0)
df.head()
# Out:
#                          Name  \
# 0                Breaking Bad
# 1                     Firefly
# 2  Avatar: The Last Airbender
# 3                    Sherlock
# 4             Attack on Titan
#
#                                              Summary  Average Runtime  \
# 0  Breaking Bad follows protagonist Walter White,...             60.0
# 1  Five hundred years in the future, a renegade c...             64.0
# 2  Water. Earth. Fire. Air. Only the Avatar was t...             30.0
# 3  Sherlock Holmes and Dr. John Watson's adventur...             90.0
# 4  Known in Japan as Shingeki no Kyojin, many yea...             26.0
#
#      End Date Premiere Date                                       Genres  \
# 0  20/01/2008    11/10/2019               ['Drama', 'Crime', 'Thriller']
# 1  20/09/2002    20/12/2002    ['Drama', 'Adventure', 'Science-Fiction']
# 2  21/02/2005    19/07/2008           ['Action', 'Adventure', 'Fantasy']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1533 entries, 0 to 1532
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             1533 non-null   object
#  1   Summary          1533 non-null   object
#  2   Average Runtime  1533 non-null   float64
#  3   End Date         1533 non-null   object
#  4   Premiere Date    1533 non-null   object
#  5   Genres           1533 non-null   object
#  6   Type             1533 non-null   object
#  7   Language         1533 non-null   object
#  8   Network          1533 non-null   object
#  9   Rating           1533 non-null   float64
#  10  Schedule (days)  1533 non-null   object
#  11  Schedule (time)  1533 non-null   object
#  12  Total Seasons    1533 non-null   int64
#  13  Total Episodes   1533 non-null   int64
#  14  Character Names  1533 non-null   object
#  15  Person Names     1533 non-null   object
# ...

# %%
df.nunique()
# Out:
# Name               1502
# Summary            1533
# Average Runtime      72
# End Date           1247
# Premiere Date      1201
# Genres              250
# Type                 10
# Language             10
# Network             140
# Rating               56
# Schedule (days)      33
# Schedule (time)      60
# Total Seasons        43
# Total Episodes      341
# Character Names    1302
# Person Names       1370
# Official Site       783
# dtype: int64

# %%
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# Animation      7.412766
# Documentary    3.301176
# Game Show      2.511111
# News           3.780000
# Panel Show     5.200000
# Reality        2.830612
# Scripted       6.980971
# Sports         6.542857
# Talk Show      5.388235
# Variety        4.352941
# Name: Rating, dtype: float64

# %%
df.describe().astype(int)
# Out:
#        Average Runtime  Rating  Total Seasons  Total Episodes
# count             1533    1533           1533            1533
# mean                51       6              5             120
# std                 19       2              6             362
# min                  0       0              1               0
# 25%                 30       6              1              13
# 50%                 60       7              3              40
# 75%                 60       7              7             110
# max                190       9             63            6850

# %%
df.sort_values(by="Rating")
# Out:
#                                         Name  \
# 1532                          The Ambassador
# 1355                        The Glee Project
# 1354  Newport Harbor: The Real Orange County
# 1353                             Talking Bad
# 1352                          The Real World
# ...                                      ...
# 9                            Game of Thrones
# 10                         The Twilight Zone
# 6                                  One Piece
# 1                                    Firefly
# 0                               Breaking Bad
#
#                                                 Summary  Average Runtime  \
# 1532  The Ambassador follows the private and politic...             50.0
# 1355  During the 11 week run of season two of The Gl...             60.0
# 1354  Chrissy, Clay, Allie, Grant, Chase, Taylor and...             30.0
# 1353  Talking Bad features Hardwick spending time wi...             30.0
# ...

# %%
df.pivot_table(index='Type', columns=('Language'),values='Rating').mean()
# Out:
# Language
# Danish        8.000000
# Dutch         0.564286
# English       4.840313
# French        1.900000
# German        8.000000
# Japanese      3.917647
# Korean        7.700000
# Portuguese    0.000000
# Spanish       1.000000
# Swedish       7.500000
# dtype: float64

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind='line',title='Top-rated TV_Shows by Genre and Kanguage', ylabel='Type',xlabel='Language	')
# Out:
# <Axes: title={'center': 'Top-rated TV_Shows by Genre and Kanguage'}, xlabel='Language\t', ylabel='Type'>
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# C:\Users\USER\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
